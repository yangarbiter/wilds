# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds_name = "celebA"

algos = {
    "DP IW": [
        "weightederm-dp_resnet50-dpsgd_1e-5_0.1_1.0_0.0001",
        #"weightederm-dp_resnet50-dpsgd_1e-5_0.01_1.0_0.0001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.001_1.0_0.0001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.01_0.1_0.0001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.1_0.1_0.0001",
        "weightederm-dp_resnet50-dpsgd_1e-5_1.0_0.1_0.0001",
        "weightederm-dp_resnet50-dpsgd_1e-5_10.0_0.1_0.0001",
        
        
    ],
    "DP gDRO": [
        #"groupdro-dp_resnet50-dpsgd_1e-5_0.01_0.1_0.0001",
        "groupdro-dp_resnet50-dpsgd_1e-5_0.1_0.1_0.0001",
        "groupdro-dp_resnet50-dpsgd_1e-5_1.0_0.1_0.0001",
        "groupdro-dp_resnet50-dpsgd_1e-5_10.0_0.1_0.0001",
    ]
}
cols = ["acc_avg", "acc_wg", "acc_y:notblond_male:0", "acc_y:notblond_male:1", "acc_y:blond_male:0", "acc_y:blond_male:1"]
col_names = ["acc", "acc_wg", "notblond_male:0", "notblond_male:1", "blond_male:0", "blond_male:1"]

best_test_results = {}
for name, log_paths in algos.items():
    for log_path in log_paths:
        df = pd.read_csv(f"../logs/{ds_name}/{log_path}/train_eval.csv")
        train_res = df[["epoch", "acc_avg", "acc_wg"]].values.tolist()
        
        df = pd.read_csv(f"../logs/{ds_name}/{log_path}/val_eval.csv")
        val_res = df[["epoch", "acc_avg", "acc_wg"]].values.tolist()
        val_res = sorted(val_res, key=lambda x: x[2])
        best_epoch_no = val_res[-1][0]

        df = pd.read_csv(f"../logs/{ds_name}/{log_path}/test_eval.csv")
        res = df[["epoch", "acc_avg", "acc_wg"]].values.tolist()
        for ent in res:
            if ent[0] == best_epoch_no:
                test_res = [val_res[-1][1], val_res[-1][2], ent[1], ent[2]]
                break
        #print(best_epoch_no)
        #test_res = [val_res[-1][1], val_res[-1][2], res[-1][1], res[-1][2], train_res[-1][1], train_res[-1][2]]

        best_test_results.setdefault(name, list()).append(test_res)

for name in algos.keys(): 
    res = np.array(best_test_results[name])
    print(name, res[res[:, 1].argmax()])
# Out:
# DP IW [0.91402829 0.90017575 0.91934675 0.87777776]
# DP gDRO [0.79976845 0.7087912  0.80963832 0.72777778]

# %%
best_test_results
# Out:
# {'DP IW': [[0.9138269424438475,
#    0.8870533108711243,
#    0.9166917204856871,
#    0.8500000238418579],
#   [0.909951150417328,
#    0.8835383653640747,
#    0.9117323160171508,
#    0.855555534362793],
#   [0.8697840571403503,
#    0.8500292897224426,
#    0.8813245296478271,
#    0.7555555701255798],
#   [0.4481804072856903,
#    0.395601749420166,
#    0.4417893886566162,
#    0.3984074294567108]],
#  'DP gDRO': [[0.7997684478759766,
#    0.708791196346283,
#    0.8096383213996887,
#    0.7277777791023254],
#   [0.584084153175354,
#    0.5291203260421753,
#    0.5987375974655151,
#    0.5309886932373047]]}

# %%
ds_name = "utkface"

algos = {
    "ERM": [
        "erm-resnet50",
    ],
    "IWERM": [
        "iwerm-resnet50",
        "iwerm-resnet50_wd0.001",
        "iwerm-resnet50_wd0.01",
        "iwerm-resnet50_wd0.1",
    ],
    "gDRO": [
        "groupDRO-resnet50",
        "groupDRO-resnet50_wd0.001",
        "groupDRO-resnet50_wd0.01",
        "groupDRO-resnet50_wd0.1",
    ],
    "ERM IW": [
        "erm_reweight-resnet50",
        "erm_reweight-resnet50_wd0.001",
        "erm_reweight-resnet50_wd0.01",
        "erm_reweight-resnet50_wd0.1",
    ],
    "noise IWERM": [
        "iwerm-resnet50-lr1e-3-noisesgd_1e-5_0.0001__",
        "iwerm-resnet50-lr1e-3-noisesgd_1e-5_0.1__",
        "iwerm-resnet50-lr1e-3-noisesgd_1e-5_10.0__",
    ],
    "DP IW": [
        "weightederm-cw0.001-dp_resnet50-lr1e-3-dpsgd_1e-5_0.01_1.0_0.001",
        "weightederm-cw0.001-dp_resnet50-lr1e-3-dpsgd_1e-5_0.1_1.0_0.001",
        "weightederm-cw0.001-dp_resnet50-lr1e-3-dpsgd_1e-5_1.0_1.0_0.001",
        
        "weightederm-cw0.002-dp_resnet50-lr1e-3-dpsgd_1e-5_0.01_1.0_0.001",
        "weightederm-cw0.002-dp_resnet50-lr1e-3-dpsgd_1e-5_0.1_1.0_0.001",
        "weightederm-cw0.002-dp_resnet50-lr1e-3-dpsgd_1e-5_1.0_1.0_0.001",
        
        "weightederm-dp_resnet50-lr1e-4-dpsgd_1e-5_0.001_1.0_0.001",
        "weightederm-dp_resnet50-lr1e-4-dpsgd_1e-5_0.01_1.0_0.001",
        "weightederm-dp_resnet50-lr1e-4-dpsgd_1e-5_0.1_1.0_0.001",
        "weightederm-dp_resnet50-lr1e-4-dpsgd_1e-5_1.0_1.0_0.001",
        
        "weightederm-dp_resnet50-lr1e-2-dpsgd_1e-5_0.001_1.0_0.001",
        "weightederm-dp_resnet50-lr1e-2-dpsgd_1e-5_0.01_1.0_0.001",
        "weightederm-dp_resnet50-lr1e-2-dpsgd_1e-5_0.1_1.0_0.001",
        "weightederm-dp_resnet50-lr1e-2-dpsgd_1e-5_1.0_1.0_0.001",
        
        "weightederm-dp_resnet50-dpsgd_1e-5_0.001_10.0_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.01_10.0_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.1_10.0_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_1.0_10.0_0.001",
        
        "weightederm-dp_resnet50-dpsgd_1e-5_0.001_0.1_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.01_0.1_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.1_0.1_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_1.0_0.1_0.001",
        
        "weightederm-dp_resnet50-dpsgd_1e-5_0.001_1.0_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.01_1.0_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_0.1_1.0_0.001",
        "weightederm-dp_resnet50-dpsgd_1e-5_1.0_1.0_0.001",
    ],
    "DP gDRO": [
        "groupdro-dp_resnet50-dpsgd_1e-5_0.01_1.0_0.001",
    ],
}

best_test_results = {}
for name, log_paths in algos.items():
    for log_path in log_paths:
        try:
            df = pd.read_csv(f"../logs/{ds_name}/{log_path}/train_eval.csv")
        except:
            print(f"{log_path} not run yet.")
            continue
            
        train_res = df[["epoch", "acc_avg", "acc_wg"]].values.tolist()
        
        df = pd.read_csv(f"../logs/{ds_name}/{log_path}/val_eval.csv")
        val_res = df[["epoch", "acc_avg", "acc_wg"]].values.tolist()
        val_res = sorted(val_res, key=lambda x: x[2])
        best_epoch_no = val_res[-1][0]

        df = pd.read_csv(f"../logs/{ds_name}/{log_path}/test_eval.csv")
        res = df[["epoch", "acc_avg", "acc_wg"]].values.tolist()
        for ent in res:
            if ent[0] == best_epoch_no:
                test_res = [val_res[-1][1], val_res[-1][2], ent[1], ent[2]]
                break

        #test_res = [val_res[-1][1], val_res[-1][2], res[-1][1], res[-1][2], train_res[-1][1], train_res[-1][2]]
        best_test_results.setdefault(name, list()).append(test_res)
        
for name in algos.keys(): 
    res = np.array(best_test_results[name])
    print(name, res[res[:, 1].argmax()])
# Out:
# weightederm-cw0.002-dp_resnet50-lr1e-3-dpsgd_1e-5_0.1_1.0_0.001 not run yet.
# weightederm-cw0.002-dp_resnet50-lr1e-3-dpsgd_1e-5_1.0_1.0_0.001 not run yet.
# ERM [0.9235     0.86885244 0.90505522 0.82508248]
# IWERM [0.94300002 0.88524592 0.9267205  0.86468649]
# gDRO [0.92150003 0.89240509 0.91737467 0.88499999]
# ERM IW [0.93099999 0.89808917 0.91928631 0.85148513]
# noise IWERM [0.91799998 0.89041096 0.91397619 0.85714287]
# DP IW [0.89950001 0.85526317 0.87786746 0.80952382]
# DP gDRO [0.89249998 0.85245901 0.88423961 0.76897693]

# %%
best_test_results
# Out:
# {'ERM': [[0.9235000014305116,
#    0.868852436542511,
#    0.9050552248954772,
#    0.8250824809074402]],
#  'IWERM': [[0.9254999756813048,
#    0.868852436542511,
#    0.9052676558494568,
#    0.8571428656578064],
#   [0.9300000071525574,
#    0.868852436542511,
#    0.9073916673660278,
#    0.8465346693992615],
#   [0.9430000185966492,
#    0.8852459192276001,
#    0.9267204999923706,
#    0.8646864891052246],
#   [0.9204999804496764,
#    0.8662420511245728,
#    0.9018691778182985,
#    0.8118811845779419]],
#  'gDRO': [[0.921500027179718,
#    0.892405092716217,
#    0.9173746705055236,
#    0.8849999904632568],
#   [0.9369999766349792,
#    0.892405092716217,
#    0.9141886234283448,
#    0.8646864891052246],
#   [0.9394999742507936,
#    0.892405092716217,
#    0.917162299156189,
#    0.867986798286438],
#   [0.9104999899864196,
#    0.8493150472640991,
#    0.9167374968528748,
#    0.8684931397438049]],
#  'ERM IW': [[0.9089999794960022,
#    0.874015748500824,
#    0.9186491370201112,
#    0.8657534122467041],
#   [0.9294999837875366,
#    0.8852459192276001,
#    0.9120645523071288,
#    0.867986798286438],
#   [0.930999994277954,
#    0.8980891704559326,
#    0.91928631067276,
#    0.8514851331710815],
#   [0.92849999666214,
#    0.8524590134620667,
